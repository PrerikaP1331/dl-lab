# %% [markdown]
# <a href="https://colab.research.google.com/github/PrerikaP1331/dl-lab/blob/main/comparing_cnn_architectures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
def build_model(name):
    input_shape = (32, 32, 3)
    num_classes = 10

    # We use .lower() to make the name matching case-insensitive
    name_clean = name.lower().replace("-", "")

    if name_clean == "lenet5":
        return models.Sequential([
            layers.Conv2D(6, (5, 5), activation='relu', input_shape=input_shape),
            layers.AveragePooling2D(pool_size=(2,2)),
            layers.Conv2D(16, (5, 5), activation='relu'),
            layers.AveragePooling2D(pool_size=(2,2)),
            layers.Flatten(),
            layers.Dense(120, activation='relu'),
            layers.Dense(84, activation='relu'),
            layers.Dense(num_classes, activation='softmax')
        ], name=name)


    elif name_clean == "alexnet":
        return models.Sequential([
            layers.Conv2D(96, (3,3), padding='same', activation='relu', input_shape=input_shape),
            layers.MaxPooling2D(pool_size=(2,2)),
            layers.Conv2D(256, (5,5), padding='same', activation='relu'),
            layers.MaxPooling2D(pool_size=(2,2)),
            layers.Conv2D(384, (3,3), padding='same', activation='relu'),
            layers.Conv2D(384, (3,3), padding='same', activation='relu'),
            layers.Conv2D(256, (3,3), padding='same', activation='relu'),
            layers.MaxPooling2D(pool_size=(2,2)),
            layers.Flatten(),
            layers.Dense(512, activation='relu'),
            layers.Dropout(0.5),
            layers.Dense(512, activation='relu'),
            layers.Dense(num_classes, activation='softmax')
        ], name=name)

    elif name_clean == "vgg16":
        return applications.VGG16(weights=None, input_shape=input_shape, classes=num_classes)

    elif name_clean == "vgg19":
        return applications.VGG19(weights=None, input_shape=input_shape, classes=num_classes)

    elif name_clean == "resnet50":
        return applications.ResNet50(weights=None, input_shape=input_shape, classes=num_classes)

    # Safety Catch
    raise ValueError(f"Model name '{name}' not recognized!")

# %%
model_names = ["LeNet-5", "AlexNet", "VGG16", "VGG19", "ResNet50"]
all_histories = {}

for name in model_names:
    print(f"\n🚀 Training: {name}...")
    try:
        model = build_model(name)
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

        # Reduced epochs to 3 for a quick initial test
        history = model.fit(x_train, y_train,
                            epochs=3,
                            batch_size=128,
                            validation_data=(x_test, y_test),
                            verbose=1)
        all_histories[name] = history
    except Exception as e:
        print(f"❌ Failed to train {name}: {e}")
# Out:
# 🚀 Training: LeNet-5...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - accuracy: 0.3397 - loss: 1.8090 - val_accuracy: 0.4368 - val_loss: 1.5634
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 92ms/step - accuracy: 0.4507 - loss: 1.5230 - val_accuracy: 0.4712 - val_loss: 1.4749
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 88ms/step - accuracy: 0.4906 - loss: 1.4291 - val_accuracy: 0.4964 - val_loss: 1.3954
#
# 🚀 Training: AlexNet...
# Epoch 1/3
#  65/391 ━━━━━━━━━━━━━━━━━━━━ 35:53 7s/step - accuracy: 0.1129 - loss: 2.2977

# %%
plt.figure(figsize=(10, 5))
for name, history in all_histories.items():
    plt.plot(history.history['val_accuracy'], label=name)

plt.title('CIFAR-10 Accuracy Comparison')
plt.ylabel('Validation Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications
import matplotlib.pyplot as plt
import numpy as np

# --- 1. DATA PREPARATION ---
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# --- 2. THE MODEL FACTORY (Fixed String Matching) ---
def build_model(name):
    input_shape = (32, 32, 3)
    num_classes = 10

    # We use .lower() to make the name matching case-insensitive
    name_clean = name.lower().replace("-", "")

    if name_clean == "lenet5":
        return models.Sequential([
            layers.Conv2D(6, (5, 5), activation='relu', input_shape=input_shape),
            layers.AveragePooling2D(pool_size=(2,2)),
            layers.Conv2D(16, (5, 5), activation='relu'),
            layers.AveragePooling2D(pool_size=(2,2)),
            layers.Flatten(),
            layers.Dense(120, activation='relu'),
            layers.Dense(84, activation='relu'),
            layers.Dense(num_classes, activation='softmax')
        ], name=name)

    elif name_clean == "alexnet":
        return models.Sequential([
            layers.Conv2D(96, (3,3), padding='same', activation='relu', input_shape=input_shape),
            layers.MaxPooling2D(pool_size=(2,2)),
            layers.Conv2D(256, (5,5), padding='same', activation='relu'),
            layers.MaxPooling2D(pool_size=(2,2)),
            layers.Conv2D(384, (3,3), padding='same', activation='relu'),
            layers.Conv2D(384, (3,3), padding='same', activation='relu'),
            layers.Conv2D(256, (3,3), padding='same', activation='relu'),
            layers.MaxPooling2D(pool_size=(2,2)),
            layers.Flatten(),
            layers.Dense(512, activation='relu'),
            layers.Dropout(0.5),
            layers.Dense(512, activation='relu'),
            layers.Dense(num_classes, activation='softmax')
        ], name=name)

    elif name_clean == "vgg16":
        return applications.VGG16(weights=None, input_shape=input_shape, classes=num_classes)

    elif name_clean == "vgg19":
        return applications.VGG19(weights=None, input_shape=input_shape, classes=num_classes)

    elif name_clean == "resnet50":
        return applications.ResNet50(weights=None, input_shape=input_shape, classes=num_classes)

    # Safety Catch
    raise ValueError(f"Model name '{name}' not recognized!")

# --- 3. THE COMPARISON LOOP ---
# Use these exact strings
model_names = ["LeNet-5", "AlexNet", "VGG16", "VGG19", "ResNet50"]
all_histories = {}

for name in model_names:
    print(f"\n🚀 Training: {name}...")
    try:
        model = build_model(name)
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

        # Reduced epochs to 3 for a quick initial test
        history = model.fit(x_train, y_train,
                            epochs=3,
                            batch_size=128,
                            validation_data=(x_test, y_test),
                            verbose=1)
        all_histories[name] = history
    except Exception as e:
        print(f"❌ Failed to train {name}: {e}")

# --- 4. VISUALIZATION ---
plt.figure(figsize=(10, 5))
for name, history in all_histories.items():
    plt.plot(history.history['val_accuracy'], label=name)

plt.title('CIFAR-10 Accuracy Comparison')
plt.ylabel('Validation Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
